# %%
# Insight 1
# Em qual competição internacional o Brasil é mais vitorioso (por índice de vitórias / jogos competidos)?
# %run insights1.py
# Out:
# Deseja considerar os amistosos na análise? (S/N):  S
# Deseja que a análise seja baseada em:
# 1 - Números absolutos (total de vitórias)
# 2 - Índice (percentual de vitórias)
# Digite 1 ou 2:  1
# Os torneios com mais vitórias do Brasil são:
#                   tournament  Jogos  Vitórias
#                     Friendly    438       299
#                 Copa América    195       114
# FIFA World Cup qualification    137        87
#               FIFA World Cup    114        79
#           Confederations Cup     33        23
# Resultados completos:
#                   tournament  Jogos  Vitórias  Derrotas  Empates
#                     Friendly    438       299        55       84
#                 Copa América    195       114        50       31
# FIFA World Cup qualification    137        87        16       34
#               FIFA World Cup    114        79        21       14
#           Confederations Cup     33        23         5        5
#    Pan American Championship     16        11         2        3
#            Copa Oswaldo Cruz     16        11         1        4
#                    Copa Roca     23        11         9        3
#              Copa Rio Branco     18         8         4        6
#                     Gold Cup     14         8         4        2
#      Copa Bernardo O'Higgins     10         6         2        2
# Superclásico de las Américas      8         4         3        1
#                 Atlantic Cup      5         3         1        1
#      Brazil Independence Cup      4         3         0        1
#           Lunar New Year Cup      1         1         0        0
#                   Mundialito      3         1         1        1
#                   King's Cup      1         1         0        0
#                     Rous Cup      2         1         0        1
#            Tournoi de France      3         1         0        2
#                      USA Cup      3         1         0        2

# %%
# Insight 2
# Qual o time mais vitorioso em cada competição internacional?
# %run insights2.py

# %%
# Insight 3
# Qual a década mais vitoriosa do Brasil, incluindo amistosos?
# %run insights3.py

# %%
# Insight 4
# Qual time mais venceu o Brasil (incluindo amistosos)?
# %run insights4.py

# %%
# Insight 5
# Qual jogador brasileiro fez mais gols de penalti?
# %run insights5.py

# %%
# Insight 6
# Quais os 5 times que mais tomaram gols do Brasil? 
# %run insights6.py
